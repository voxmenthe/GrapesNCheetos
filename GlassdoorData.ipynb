# %% [markdown]
# ## Getting Employer Data

# %%
from fake_useragent import UserAgent
ua = UserAgent()
#ua.chrome
headers = ua.firefox
#ua.random

# %%
def getEmployerDataOld(links,header,maxerrors=10):
    result = {}
    import urllib, requests # json
    #headers = {'User-Agent': 'Mozillia/5.0'}
    headers = {'User-Agent':'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_5)'}
    counter = 1
    errorcounter = 1
    for link in links:
        try:
            time.sleep(random.random())
            time.sleep(random.random())
            response = urllib.urlopen(link)
            data = requests.get(link,headers=inputheaders) #, params=params) # json.loads(response.read())
            result[link] = data
            print("Success: ",counter)
            counter += 1
        except:
            print("Error getting data")
            print("Error: ",errorcounter)
            errorcounter += 1
            if errorcounter >= maxerrors:
                return result
    return result
# Out:
#   File "<ipython-input-43-6323726533bf>", line 13
#     data = requests.get(link,headers=Accept:text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8
#                                            ^
# SyntaxError: invalid syntax

# %%
baseurl = 'http://api.glassdoor.com/api/api.htm?t.p=81406&t.k=eGBibnr4ZSM&userip=208.184.96.233&useragent=&format=json&v=1&action=employers'

# %%
# Use the function to fake the headers
base_url = 'http://api.glassdoor.com/api/api.htm'
# t.p=81406&t.k=eGBibnr4ZSM&userip=&useragent=&format=json&v=1&action=employers&pn=2'

params = {
    "t.p": "81406",
    "t.k": "eGBibnr4ZSM",
    "userip": "208.184.96.233",
    "format": "json",
    "v": "1",
    "action": "employers",
    #"pn": 20000
}
# response, soup = connection(base_url,params=params)

# %%
import requests
import time
from bs4 import BeautifulSoup
# from fake_useragent import UserAgent
import random
import json

# sometimes things work more smoothly if we change the User-Agent in the request headers
def connection(url, params):
#    ua = UserAgent()
    headers = {'User-Agent':'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_5)'}
#     headers = {
#         "User-Agent": ua.random
#     }
    r = requests.get(url,headers=headers, params=params)
    soup = None
    if r.ok:
        return r.json()
        soup = BeautifulSoup(r.text, "html.parser")
    else:
        print('request unsuccessful with code %s'%response.status_code)
    return r, soup

def getEmployerData(pagestart=1,pageend=10):
    result = {}
    counter = 1
    errorcounter = 1
    
    base_url = 'http://api.glassdoor.com/api/api.htm'
    
    params = {
        "t.p": "81406",
        "t.k": "eGBibnr4ZSM",
        "userip": "50.143.148.239",   # "208.184.96.233",
        "format": "json",
        "v": "1",
        "action": "employers",
        "pn": 1
        }
       
    for x in range(pagestart,pageend+1):
        time.sleep(random.random())
        time.sleep(random.random())
        params["pn"] = counter
        json_data = connection(base_url,params=params)
        
        # save json files
        filename = 'employerdata_' + str(x) + '.json'
        with open(filename, 'w') as outfile:
            json.dump(json_data, outfile)
        
        print("Success: ",counter)
        counter += 1
    
    return result

# running the function - remember to put in a separate cell
#pages5 = getEmployerData(pagestart=1,pageend=5,maxerrors=3)

# %%
getEmployerData(pagestart=2101,pageend=3000)
# Out:
# Success:  1
# Success:  2
# Success:  3
# Success:  4
# Success:  5
# Success:  6
# Success:  7
# Success:  8
# Success:  9
# Success:  10
# Success:  11
# Success:  12
# Success:  13
# Success:  14
# Success:  15
# Success:  16
# Success:  17
# Success:  18
# Success:  19
# Success:  20
# Success:  21
# Success:  22
# Success:  23
# Success:  24
# Success:  25
# Success:  26
# Success:  27
# Success:  28
# Success:  29
# Success:  30
# Success:  31
# Success:  32
# Success:  33
# Success:  34
# Success:  35
# Success:  36
# Success:  37
# Success:  38
# Success:  39
# Success:  40
# Success:  41
# Success:  42
# Success:  43
# Success:  44
# Success:  45
# Success:  46
# Success:  47
# Success:  48
# Success:  49
# Success:  50
# Success:  51
# Success:  52
# Success:  53
# Success:  54
# Success:  55
# Success:  56
# Success:  57
# Success:  58
# Success:  59
# Success:  60
# Success:  61
# Success:  62
# Success:  63
# Success:  64
# Success:  65
# Success:  66
# Success:  67
# ...
